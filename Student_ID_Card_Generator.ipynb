# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijayravi96/Python_Fundamental_Codes/blob/main/Student_ID_Card_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Case Study – Student ID Card Generator

# Get input from the user
student_name = input("Enter Student Name: ")
roll_number = input("Enter Roll Number: ")
department = input("Enter Department: ")

# Convert to uppercase
student_name = student_name.upper()
department = department.upper()

# Extract first 4 letters
name_part = student_name[:4]
dept_part = department[:4]

# Generate Student ID
student_id = f"{name_part}{dept_part}{roll_number}"

# Display details
print("\n----- Student ID Card -----")
print(f"Name        : {student_name}")
print(f"Department  : {department}")
print(f"Roll Number : {roll_number}")
print(f"Student ID  : {student_id}")
# Out:
# Enter Student Name: Vijay
# Enter Roll Number: 101
# Enter Department: Data Analytics
#
# ----- Student ID Card -----
# Name        : VIJAY
# Department  : DATA ANALYTICS
# Roll Number : 101
# Student ID  : VIJADATA101
