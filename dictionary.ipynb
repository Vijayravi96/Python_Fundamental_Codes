# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijayravi96/Python_Fundamental_Codes/blob/main/dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [21, 22, 23],
    "course": ["Data Science", "AI", "Machine Learning"]
}

print(student.keys())
# Out:
# dict_keys(['name', 'age', 'course'])

# %%
courses = {"Python", "SQL", "Power BI", "Python", "Excel"}

print(courses)
courses = {"Python", "SQL", "Power BI", "Excel"}

courses.add("Tableau")

print(courses)
courses = {"Python", "SQL", "Power BI", "Excel"}

courses.update(["Tableau", "Pandas", "NumPy"])

print(courses)
courses = {"Python", "SQL", "Power BI", "Excel"}

courses.remove("SQL")

print(courses)
courses = {"Python", "SQL", "Power BI", "Excel"}

courses.discard("Excel")

print(courses)
courses = {"Python", "SQL", "Power BI", "Excel"}

print("Courses:", courses)
print("Total number of courses:", len(courses))
# Out:
# {'Power BI', 'SQL', 'Excel', 'Python'}
# {'SQL', 'Excel', 'Tableau', 'Python', 'Power BI'}
# {'SQL', 'Excel', 'Tableau', 'NumPy', 'Python', 'Pandas', 'Power BI'}
# {'Power BI', 'Excel', 'Python'}
# {'Power BI', 'SQL', 'Python'}
# Courses: {'Power BI', 'SQL', 'Excel', 'Python'}
# Total number of courses: 4

# %%
student = {
    "name": [],
    "age": [],
    "course": []
}
student = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [21, 22, 23],
    "course": ["Data Science", "AI", "Machine Learning"]
}
student = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [21, 22, 23],
    "course": ["Data Science", "AI", "Machine Learning"]
}

# Add new student details
student["name"].append("David")
student["age"].append(24)
student["course"].append("Python")
student["name"].append("David")
student["age"].append(24)
student["course"].append("Python")
student = {
    "name": ["Alice", "Bob", "Charlie", "David"],
    "age": [21, 22, 23, 24],
    "course": ["Data Science", "AI", "Machine Learning", "Python"]
}

print("Names:", student["name"])
print("Ages:", student["age"])
print("Courses:", student["course"])
student = {
    "name": ["Alice", "Bob", "Charlie", "David"],
    "age": [21, 22, 23, 24],
    "course": ["Data Science", "AI", "Machine Learning", "Python"]
}

print("First Student Details:")
print("Name:", student["name"][0])
print("Age:", student["age"][0])
print("Course:", student["course"][0])
student = {
    "name": ["Alice", "Bob", "Charlie", "David"],
    "age": [21, 22, 23, 24],
    "course": ["Data Science", "AI", "Machine Learning", "Python"]
}

print("Newly Added Student Details:")
print("Name:", student["name"][3])
print("Age:", student["age"][3])
print("Course:", student["course"][3])
# Out:
# Names: ['Alice', 'Bob', 'Charlie', 'David']
# Ages: [21, 22, 23, 24]
# Courses: ['Data Science', 'AI', 'Machine Learning', 'Python']
# First Student Details:
# Name: Alice
# Age: 21
# Course: Data Science
# Newly Added Student Details:
# Name: David
# Age: 24
# Course: Python
